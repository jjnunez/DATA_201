# %%
## Import `os'
import os

# %%
## Now that `os' is downloaded, I'm going to save the command to get the working directory as `cwd'

cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\Juan Nunez'

# %%
## Now I want to change my working directory to the folder that contains my project files.
os.chdir("C:/Users/Juan Nunez/Desktop/DATA_201")
cwd
# Out:
# 'C:\\Users\\Juan Nunez'

# %%
## Now I list all files and directories in the current directory
os.listdir('.')
# Out:
# ['.git',
#  'ASSIG1_DATA.csv',
#  'ASSIG1_DATA.xlsx',
#  'Basic Matplotlib.ipynb',
#  'Basic Numpy.ipynb',
#  'Basic Pandas.ipynb',
#  'Basic Python 1.ipynb',
#  'LESDATA.csv',
#  'Project_1.ipynb',
#  'SPSS_DATA_FOR_Python.sav']

# %%
## I start by importing pandas and then I assign the project spreadsheet to the file named `PROJECT1_DATA'
import pandas as pd
PROJECT1_DATA = "ASSIG1_DATA.xlsx"

# %%
## Once the command above runs, I load the spreadsheet
WB_DATA = pd.ExcelFile(PROJECT1_DATA)

# %%
## Now I want to print the sheet names
print(WB_DATA.sheet_names)
# Out:
# ['in']

# %%
## Finally, I load the sheet into a DataFrame using the name : WB_DF
WB_DF = WB_DATA.parse('in')
WB_DF.head()
# Out:
#     V1    V2           V3             V4    V5    V6    V7             V8  \
# 1  1.0  AFGN  Afghanistan  1.831347e-317  86.0   NaN   NaN  4.770435e-312
# 2  2.0  ALBN      Albania   3.500000e+01   NaN   NaN   NaN  4.770435e-312
# 3  3.0  ALGR      Algeria   5.300000e+01  55.0  42.0  36.0  1.068570e-314
# 4  4.0  ANGL       Angola   2.800000e+01  72.0  29.0   NaN  6.716447e-318
# 5  5.0  ARGN    Argentina   8.700000e+01   5.0   NaN   NaN  1.068606e-314
#
#                      V9            V10  \
# 1           4.66726e-62  1.992802e-314
# 2           4.66726e-62  1.992802e-314
# 3  4.1517640553345e-317  1.992802e-314
# 4           4.66726e-62  1.992802e-314
# 5         -1.54235e-180  2.279817e-319
#
#                          ...                          V347  V348  \
# 1                        ...                          30.0   1.0
# 2                        ...                          23.0   0.0
# 3                        ...                          51.0   0.0
# ...

# %%
## Now that the DataFrame seems to be succesfully uploaded to Python, I will start with the project. 
## I start by looking at the dimension of the Dataframe
WB_DF.shape
# Out:
# (148, 356)

# %%
## We see above that the DataFrame has 148 rows and 356 columns
##I see that the countries at the top of this data frame are Afghanistan, Albania, Algeria, Angola, Argentina, and Armenia. 
##This data frame has way too many variables (i.e., columns) so I have to take a subset of the variables that I want to use. 
##To take a subset of the data frame, I use the function 'select()'. The variables I am keeping are as coded as follows:

##V1 COUNTRY NUMBER ; 
##V2 ABBREVIATED COUNTRY NAME ; 
##V3 COUNTRY NAME ; 
##V5 % ADULT FEMALE ILLITERACY 1990 ; 
##V12 ENERGY CONSUMPTION/CAPITA 1991 ; 
##V14 INFANT MORTALITY RATE 1991 ; 
##V168 FEMALE SECODARY SCHOOL ENROLLMENT GROSS 1980 ; 
##V133 CIVIL LIBERTIES 1991 ; 

list(WB_DF.items())
# Out:
# [('V1', 1       1.000000e+00
#   2       2.000000e+00
#   3       3.000000e+00
#   4       4.000000e+00
#   5       5.000000e+00
#   6       6.000000e+00
#   7       7.000000e+00
#   8       8.000000e+00
#   9       9.000000e+00
#   10      1.000000e+01
#   11      1.100000e+01
#   12      1.200000e+01
#   13      1.300000e+01
#   14      1.400000e+01
#   15      1.500000e+01
#   16      1.600000e+01
#   17      1.700000e+01
#   18      1.800000e+01
#   19      1.900000e+01
#   20      2.000000e+01
#   21      2.100000e+01
#   22      2.200000e+01
#   23      2.300000e+01
#   24      2.400000e+01
#   25      2.500000e+01
#   26      2.600000e+01
#   27      2.700000e+01
#   28      2.800000e+01
#   29      2.900000e+01
#   30      3.000000e+01
#              ...
#   119     1.190000e+02
#   120     1.200000e+02
#   121     1.210000e+02
#   122     1.220000e+02
#   123     1.230000e+02
#   124     1.240000e+02
#   125     1.250000e+02
#   126     1.260000e+02
#   127     1.270000e+02
# ...

# %%
WB_DF.tail()
# Out:
#                 V1    V2                   V3             V4  V5  V6  V7  \
# 144  1.312902e-317  USSR         Soviet Union  1.831347e-317 NaN NaN NaN
# 145  1.571935e-317   FRG  Germany, West (FGR)   8.400000e+01 NaN NaN NaN
# 146  1.830968e-317   GDR  Germany, East (GDR)  1.831347e-317 NaN NaN NaN
# 147  2.090000e-317  YMNA    Yemen ( Arab Rep)  1.831347e-317 NaN NaN NaN
# 148  2.349033e-317  YMND          Yemen (PDR)  1.831347e-317 NaN NaN NaN
#
#                 V8           V9            V10  \
# 144  4.770435e-312  4.66726e-62  1.992802e-314
# 145  1.425885e-314  4.66726e-62  1.992802e-314
# 146  4.770435e-312  4.66726e-62  1.992802e-314
# 147  4.770435e-312  4.66726e-62  1.992802e-314
# 148  4.770435e-312  4.66726e-62  1.992802e-314
#
#                            ...                          V347  V348  \
# 144                        ...                           NaN   NaN
# 145                        ...                           NaN   NaN
# ...

# %%
## I'm saving the indexes, columns, and values into variables below.

index = WB_DF.index
columns = WB_DF.columns
values = WB_DF.values
index
columns
values
# Out:
# array([[1.0, 'AFGN', 'Afghanistan', ...,
#         190359856498648004962082266373502551403083012276804970196627589971368388014052153477248596594457484960334094665405295432486127810092677982292857710162048671903010018279212887641233031168,
#         4.66726145839918e-62, -1.54234871186482e-180],
#        [2.0, 'ALBN', 'Albania', ...,
#         190359856878453997931733452181891286932962530820725364775931938351315793285447405656634116688104191114660410095802711322387155630315137958983236552009935224044504427721943432243013746688,
#         -1.54234871366007e-180,
#         738736860439138996153162944615491134006332147385673922350180217108522389887602875951891476890163291176573103254574080220295651425295269888],
#        [3.0, 'ALGR', 'Algeria', ..., -1.54234871366002e-180,
#         190359856625048996347936766588489941727319975272623011942968032592214968522024421933322547588279143787557604132700152068174498560102342993491481356422677123880031180791910244180851425280,
# ...

# %%
## Let's see what kind of objects these are
type(index)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
type(columns)
# Out:
# pandas.core.indexes.base.Index

# %%
type(values)
# Out:
# numpy.ndarray

# %%
## Below I just want to index 1 column (i.e., country name)

WB_DF['V2']
# Out:
# 1      AFGN
# 2      ALBN
# 3      ALGR
# 4      ANGL
# 5      ARGN
# 6      ARMN
# 7      AUSL
# 8      AUST
# 9      AZBJ
# 10     BNGL
# 11     BLRS
# 12     BLGM
# 13     BNIN
# 14     BTAN
# 15     BOLV
# 16     BTSN
# 17     BRZL
# 18     BLGR
# 19     BKFS
# 20     BRND
# 21     CMBA
# 22     CMRN
# 23     CNDA
# 24     CAFR
# 25     CHAD
# 26     CHLE
# 27     CHNA
# 28     CLMB
# 29     CNGO
# 30     CRCA
#        ...
# 119    SWDN
# 120    SWTZ
# 121    SYRA
# 122    TKTN
# 123    TNZN
# 124    TLND
# 125    TOGO
# 126    TRNT
# 127    TNSA
# 128    TRKY
# 129    TKMT
# 130    UGND
# 131    UKRN
# 132    UARE
# 133      UK
# 134     USA
# 135    URGY
# 136    UZBK
# 137    VNZL
# 138    VTNM
# 139    YMNR
# 140    YGSL
# 141    ZAIR
# 142    ZMBA
# 143    ZIMB
# 144    USSR
# 145     FRG
# 146     GDR
# 147    YMNA
# 148    YMND
# Name: V2, Length: 148, dtype: object

# %%
## Below I subset different columns

WB_DF2 = WB_DF[['V1', 'V2', 'V3','V5','V12','V14','V168','V133']]
WB_DF2.head()
WB_DF2.tail()
# Out:
#                 V1    V2                   V3  V5            V12  \
# 144  1.312902e-317  USSR         Soviet Union NaN  1.065394e-314
# 145  1.571935e-317   FRG  Germany, West (FGR) NaN  4.749670e-318
# 146  1.830968e-317   GDR  Germany, East (GDR) NaN  1.065394e-314
# 147  2.090000e-317  YMNA    Yemen ( Arab Rep) NaN  1.065394e-314
# 148  2.349033e-317  YMND          Yemen (PDR) NaN  1.065394e-314
#
#                V14           V168  V133
# 144  1.831347e-317  1.831347e-317   4.0
# 145   7.000000e+00   9.200000e+01   NaN
# 146  1.831347e-317   7.900000e+01   NaN
# 147  1.831347e-317   1.000000e+00   NaN
# 148  1.831347e-317   1.100000e+01   NaN

# %%
## Below is how we use .loc to take just one row. I'm going to look at all of the values for USA, whose index is 134.
WB_DF.loc[134]
# Out:
# V1                                                    134
# V2                                                    USA
# V3                                          United States
# V4                                                     75
# V5                                                      2
# V6                                                     17
# V7                                                     74
# V8                                           6.33313e-315
# V9                                                    100
# V10                                          1.06608e-314
# V11                                          1.06608e-314
# V12                                          5.64421e-319
# V13                                                   NaN
# V14                                                     9
# V15     -606598799380313964016330604036392640690209388...
# V16     -606598800007353970071405179413357454301251509...
# ...

# %%
## Below I take various rows.
WB_DF.loc[[134, 17, 133]]
# Out:
#         V1    V2              V3    V4    V5    V6    V7             V8  \
# 134  134.0   USA   United States  75.0   2.0  17.0  74.0  6.333133e-315
# 17    17.0  BRZL          Brazil  76.0  20.0  34.0  65.0  1.494266e-314
# 133  133.0    UK  United Kingdom  89.0   2.0  19.0   NaN  1.431970e-314
#
#               V9            V10  \
# 134          100  1.066076e-314
# 17   4.66726e-62  3.908289e-317
# 133  4.66726e-62  7.602919e-317
#
#                            ...                          V347  V348  V349  \
# 134                        ...                          56.0   0.0   9.0
# 17                         ...                          42.0   0.0  70.0
# 133                        ...                          55.0   0.0   8.0
#
#      V350                                               V351  \
# 134  12.0                                      -1.54235e-180
# 17   76.0  -606598799537778030498068346917171621787230526...
# ...

# %%
## Below I take a range of rows. 1-57 becasue .loc keeps the last row. 
WB_DF.loc[1:57]
# Out:
#       V1    V2                    V3             V4    V5    V6    V7  \
# 1    1.0  AFGN           Afghanistan  1.831347e-317  86.0   NaN   NaN
# 2    2.0  ALBN               Albania   3.500000e+01   NaN   NaN   NaN
# 3    3.0  ALGR               Algeria   5.300000e+01  55.0  42.0  36.0
# 4    4.0  ANGL                Angola   2.800000e+01  72.0  29.0   NaN
# 5    5.0  ARGN             Argentina   8.700000e+01   5.0   NaN   NaN
# 6    6.0  ARMN               Armenia   6.800000e+01   NaN   NaN   NaN
# 7    7.0  AUSL             Australia   8.600000e+01   2.0   8.0   NaN
# 8    8.0  AUST               Austria   5.900000e+01   2.0   NaN   NaN
# 9    9.0  AZBJ            Azerbaijan   5.400000e+01   NaN   NaN   NaN
# 10  10.0  BNGL            Bangladesh   1.700000e+01  78.0  51.0  31.0
# 11  11.0  BLRS               Belarus   6.600000e+01   NaN   NaN   NaN
# 12  12.0  BLGM               Belgium   9.700000e+01   2.0   6.0   NaN
# ...

# %%
## .loc also let's me use the slice similar to python. I'll take the first 120 rows below.
WB_DF.loc[:120]
# Out:
#         V1    V2                    V3             V4    V5    V6    V7  \
# 1      1.0  AFGN           Afghanistan  1.831347e-317  86.0   NaN   NaN
# 2      2.0  ALBN               Albania   3.500000e+01   NaN   NaN   NaN
# 3      3.0  ALGR               Algeria   5.300000e+01  55.0  42.0  36.0
# 4      4.0  ANGL                Angola   2.800000e+01  72.0  29.0   NaN
# 5      5.0  ARGN             Argentina   8.700000e+01   5.0   NaN   NaN
# 6      6.0  ARMN               Armenia   6.800000e+01   NaN   NaN   NaN
# 7      7.0  AUSL             Australia   8.600000e+01   2.0   8.0   NaN
# 8      8.0  AUST               Austria   5.900000e+01   2.0   NaN   NaN
# 9      9.0  AZBJ            Azerbaijan   5.400000e+01   NaN   NaN   NaN
# 10    10.0  BNGL            Bangladesh   1.700000e+01  78.0  51.0  31.0
# 11    11.0  BLRS               Belarus   6.600000e+01   NaN   NaN   NaN
# 12    12.0  BLGM               Belgium   9.700000e+01   2.0   6.0   NaN
# ...

# %%
## Below I slice from the 10th country to the 60th country taking steps of 2.
WB_DF.loc[10:60:2]
# Out:
#       V1    V2                    V3             V4    V5    V6    V7  \
# 10  10.0  BNGL            Bangladesh   1.700000e+01  78.0  51.0  31.0
# 12  12.0  BLGM               Belgium   9.700000e+01   2.0   6.0   NaN
# 14  14.0  BTAN                Bhutan   6.000000e+00  75.0   NaN   NaN
# 16  16.0  BTSN              Botswana   2.900000e+01  35.0   NaN  33.0
# 18  18.0  BLGR              Bulgaria   6.800000e+01   NaN   NaN   NaN
# 20  20.0  BRND               Burundi   6.000000e+00  60.0  68.0   9.0
# 22  22.0  CMRN              Cameroon   4.200000e+01  57.0   8.0  16.0
# 24  24.0  CAFR  Central African Rep.   4.800000e+01  75.0  67.0   NaN
# 26  26.0  CHLE                 Chile   8.600000e+01   7.0  20.0   NaN
# 28  28.0  CLMB              Colombia   7.100000e+01  14.0  24.0  66.0
# 30  30.0  CRCA            Costa Rica   4.800000e+01   7.0   NaN   NaN
# 32  32.0  CUBA                  Cuba  1.831347e-317   NaN   NaN   NaN
# ...

# %%
## Below I slice all the way to the end starting at the 10th country.
WB_DF.loc[10:]
# Out:
#                 V1    V2                    V3             V4    V5    V6  \
# 10    1.000000e+01  BNGL            Bangladesh   1.700000e+01  78.0  51.0
# 11    1.100000e+01  BLRS               Belarus   6.600000e+01   NaN   NaN
# 12    1.200000e+01  BLGM               Belgium   9.700000e+01   2.0   6.0
# 13    1.300000e+01  BNIN                 Benin   3.800000e+01  84.0  55.0
# 14    1.400000e+01  BTAN                Bhutan   6.000000e+00  75.0   NaN
# 15    1.500000e+01  BOLV               Bolivia   5.200000e+01  29.0  36.0
# 16    1.600000e+01  BTSN              Botswana   2.900000e+01  35.0   NaN
# 17    1.700000e+01  BRZL                Brazil   7.600000e+01  20.0  34.0
# 18    1.800000e+01  BLGR              Bulgaria   6.800000e+01   NaN   NaN
# 19    1.900000e+01  BKFS          Burkina Faso   9.000000e+00  91.0  24.0
# 20    2.000000e+01  BRND               Burundi   6.000000e+00  60.0  68.0
# 21    2.100000e+01  CMBA              Cambodia   1.200000e+01  78.0   NaN
# ...

# %%
## Below I use .loc to select both rows and columns.
WB_DF.loc[[133, 134], ['V1', 'V2', 'V3', 'V5', 'V12']]
# Out:
#         V1   V2              V3   V5            V12
# 133  133.0   UK  United Kingdom  2.0  6.756636e-317
# 134  134.0  USA   United States  2.0  5.644206e-319

# %%
## Now I want to select 2 row and 1 column.
WB_DF.loc[[133, 134], 'V12']
# Out:
# 133    6.756636e-317
# 134    5.644206e-319
# Name: V12, dtype: float64

# %%
## Below I take a slice of rows and a list of columns.
WB_DF.loc[10:60, ['V1', 'V2', 'V3', 'V5']]
# Out:
#       V1    V2                    V3    V5
# 10  10.0  BNGL            Bangladesh  78.0
# 11  11.0  BLRS               Belarus   NaN
# 12  12.0  BLGM               Belgium   2.0
# 13  13.0  BNIN                 Benin  84.0
# 14  14.0  BTAN                Bhutan  75.0
# 15  15.0  BOLV               Bolivia  29.0
# 16  16.0  BTSN              Botswana  35.0
# 17  17.0  BRZL                Brazil  20.0
# 18  18.0  BLGR              Bulgaria   NaN
# 19  19.0  BKFS          Burkina Faso  91.0
# 20  20.0  BRND               Burundi  60.0
# 21  21.0  CMBA              Cambodia  78.0
# 22  22.0  CMRN              Cameroon  57.0
# 23  23.0  CNDA                Canada   2.0
# 24  24.0  CAFR  Central African Rep.  75.0
# 25  25.0  CHAD                  Chad  82.0
# 26  26.0  CHLE                 Chile   7.0
# 27  27.0  CHNA                 China  38.0
# 28  28.0  CLMB              Colombia  14.0
# 29  29.0  CNGO                 Congo  56.0
# 30  30.0  CRCA            Costa Rica   7.0
# ...

# %%
## Below I take a single row and single column.
WB_DF.loc[134, 'V3']
# Out:
# 'United States'

# %%
## Below I take a slice of rows and columns.
WB_DF.loc[:20, 'V3':]
# Out:
#               V3             V4    V5    V6    V7             V8  \
# 1    Afghanistan  1.831347e-317  86.0   NaN   NaN  4.770435e-312
# 2        Albania   3.500000e+01   NaN   NaN   NaN  4.770435e-312
# 3        Algeria   5.300000e+01  55.0  42.0  36.0  1.068570e-314
# 4         Angola   2.800000e+01  72.0  29.0   NaN  6.716447e-318
# 5      Argentina   8.700000e+01   5.0   NaN   NaN  1.068606e-314
# 6        Armenia   6.800000e+01   NaN   NaN   NaN  4.770435e-312
# 7      Australia   8.600000e+01   2.0   8.0   NaN  7.982115e-315
# 8        Austria   5.900000e+01   2.0   NaN   NaN  1.591627e-314
# 9     Azerbaijan   5.400000e+01   NaN   NaN   NaN  4.770435e-312
# 10    Bangladesh   1.700000e+01  78.0  51.0  31.0  1.068019e-314
# 11       Belarus   6.600000e+01   NaN   NaN   NaN  4.770435e-312
# 12       Belgium   9.700000e+01   2.0   6.0   NaN  5.970714e-315
# 13         Benin   3.800000e+01  84.0  55.0   NaN  3.905379e-317
# ...

# %%
## Below I select all of the rows and just a couple of columns.
WB_DF.loc[:, ['V1', 'V2', 'V3']]
# Out:
#                 V1    V2                    V3
# 1     1.000000e+00  AFGN           Afghanistan
# 2     2.000000e+00  ALBN               Albania
# 3     3.000000e+00  ALGR               Algeria
# 4     4.000000e+00  ANGL                Angola
# 5     5.000000e+00  ARGN             Argentina
# 6     6.000000e+00  ARMN               Armenia
# 7     7.000000e+00  AUSL             Australia
# 8     8.000000e+00  AUST               Austria
# 9     9.000000e+00  AZBJ            Azerbaijan
# 10    1.000000e+01  BNGL            Bangladesh
# 11    1.100000e+01  BLRS               Belarus
# 12    1.200000e+01  BLGM               Belgium
# 13    1.300000e+01  BNIN                 Benin
# 14    1.400000e+01  BTAN                Bhutan
# 15    1.500000e+01  BOLV               Bolivia
# 16    1.600000e+01  BTSN              Botswana
# 17    1.700000e+01  BRZL                Brazil
# 18    1.800000e+01  BLGR              Bulgaria
# 19    1.900000e+01  BKFS          Burkina Faso
# ...

# %%
## I can also take all of the columns and some of the rows.
WB_DF.loc[[133, 134], :]
# Out:
#         V1   V2              V3    V4   V5    V6    V7             V8  \
# 133  133.0   UK  United Kingdom  89.0  2.0  19.0   NaN  1.431970e-314
# 134  134.0  USA   United States  75.0  2.0  17.0  74.0  6.333133e-315
#
#               V9            V10  \
# 133  4.66726e-62  7.602919e-317
# 134          100  1.066076e-314
#
#                            ...                          V347  V348  V349  \
# 133                        ...                          55.0   0.0   8.0
# 134                        ...                          56.0   0.0   9.0
#
#      V350                                               V351  \
# 133  10.0  -606598799223942025094111300993882217936023149...
# 134  12.0                                      -1.54235e-180
#
#                                                   V352  \
# 133  -606598799066880986980689167360716423220263318...
# 134                                        4.66726e-62
#
# ...

# %%
## We can do the above this way as well.
WB_DF.loc[[133,134]]
# Out:
#         V1   V2              V3    V4   V5    V6    V7             V8  \
# 133  133.0   UK  United Kingdom  89.0  2.0  19.0   NaN  1.431970e-314
# 134  134.0  USA   United States  75.0  2.0  17.0  74.0  6.333133e-315
#
#               V9            V10  \
# 133  4.66726e-62  7.602919e-317
# 134          100  1.066076e-314
#
#                            ...                          V347  V348  V349  \
# 133                        ...                          55.0   0.0   8.0
# 134                        ...                          56.0   0.0   9.0
#
#      V350                                               V351  \
# 133  10.0  -606598799223942025094111300993882217936023149...
# 134  12.0                                      -1.54235e-180
#
#                                                   V352  \
# 133  -606598799066880986980689167360716423220263318...
# 134                                        4.66726e-62
#
# ...

# %%
## Below I create variables with my selections.
rows = [133, 134, 27, 34, 76]
cols = ['V2', 'V3', 'V67', 'V144']
WB_DF.loc[rows, cols]
# Out:
#        V2              V3           V67           V144
# 133    UK  United Kingdom -1.54235e-180   0.000000e+00
# 134   USA   United States            -4   4.667261e-62
# 27   CHNA           China -1.54235e-180 -1.542349e-180
# 34   DNMK         Denmark -1.54235e-180   2.000000e+00
# 76   LTNA       Lithuania -1.54235e-180 -1.542349e-180

# %%
## Below I use .iloc instead of .loc to take a row. Notice that 133 indicates the 134th row.
WB_DF.iloc[133]
# Out:
# V1                                                    134
# V2                                                    USA
# V3                                          United States
# V4                                                     75
# V5                                                      2
# V6                                                     17
# V7                                                     74
# V8                                           6.33313e-315
# V9                                                    100
# V10                                          1.06608e-314
# V11                                          1.06608e-314
# V12                                          5.64421e-319
# V13                                                   NaN
# V14                                                     9
# V15     -606598799380313964016330604036392640690209388...
# V16     -606598800007353970071405179413357454301251509...
# ...

# %%
## I use integers to select rows.
WB_DF.iloc[[135, 132, 134]]
# Out:
#         V1    V2              V3    V4   V5    V6  V7             V8  \
# 136  136.0  UZBK      Uzbekistan  41.0  NaN   NaN NaN  4.770435e-312
# 133  133.0    UK  United Kingdom  89.0  2.0  19.0 NaN  1.431970e-314
# 135  135.0  URGY         Uruguay  86.0  4.0   NaN NaN  1.065264e-314
#
#                V9            V10  \
# 136   4.66726e-62  6.626235e-317
# 133   4.66726e-62  7.602919e-317
# 135 -1.54235e-180  4.768643e-318
#
#                            ...                          V347  V348  V349  \
# 136                        ...                          35.0   0.0  47.0
# 133                        ...                          55.0   0.0   8.0
# 135                        ...                          49.0   0.0  20.0
#
#      V350                                               V351  \
# 136  59.0  1903598564987640014711715812685050478246842677...
# 133  10.0  -606598799223942025094111300993882217936023149...
# 135  28.0                                        4.66726e-62
#
# ...

# %%
## I can also slice with .iloc.
WB_DF.iloc[3:5]
# Out:
#     V1    V2         V3    V4    V5    V6  V7             V8            V9  \
# 4  4.0  ANGL     Angola  28.0  72.0  29.0 NaN  6.716447e-318   4.66726e-62
# 5  5.0  ARGN  Argentina  87.0   5.0   NaN NaN  1.068606e-314 -1.54235e-180
#
#              V10                        ...                          V347  \
# 4  1.992802e-314                        ...                          25.0
# 5  2.279817e-319                        ...                          45.0
#
#    V348           V349           V350          V351  \
# 4   0.0  1.831347e-317  1.831347e-317   4.66726e-62
# 5   0.0   3.300000e+01   3.800000e+01 -1.54235e-180
#
#                                                 V352                   V353  \
# 4                              7.26357130900034e-317          -1.54235e-180
# 5  -606598799066861980444196006434445767939750809...  4.15151109372383e-317
#
#                                                 V354  \
# 4                                        4.66726e-62
# ...

# %%
## 130th position until the end.
WB_DF.iloc[130:]
# Out:
#                 V1    V2                    V3             V4    V5    V6  \
# 131   1.310000e+02  UKRN               Ukraine   6.700000e+01   NaN   NaN
# 132   1.320000e+02  UARE  United Arab Emirates  1.831347e-317   NaN   NaN
# 133   1.330000e+02    UK        United Kingdom   8.900000e+01   2.0  19.0
# 134   1.340000e+02   USA         United States   7.500000e+01   2.0  17.0
# 135   1.350000e+02  URGY               Uruguay   8.600000e+01   4.0   NaN
# 136   1.360000e+02  UZBK            Uzbekistan   4.100000e+01   NaN   NaN
# 137   1.370000e+02  VNZL             Venezuela   8.500000e+01  10.0  29.0
# 138   1.380000e+02  VTNM               Vietnam   2.200000e+01  16.0   NaN
# 139   1.390000e+02  YMNR                 Yemen   3.000000e+01  74.0   NaN
# 140   1.400000e+02  YGSL            Yugoslavia   5.600000e+01  12.0   NaN
# 141   1.410000e+02  ZAIR                 Zaire   4.000000e+01  39.0  42.0
# 142   1.420000e+02  ZMBA                Zambia   5.100000e+01  35.0  34.0
# ...

# %%
## 130th position until the end taking steps of two.
WB_DF.iloc[130::2]
# Out:
#                 V1    V2                   V3             V4    V5    V6  \
# 131   1.310000e+02  UKRN              Ukraine   6.700000e+01   NaN   NaN
# 133   1.330000e+02    UK       United Kingdom   8.900000e+01   2.0  19.0
# 135   1.350000e+02  URGY              Uruguay   8.600000e+01   4.0   NaN
# 137   1.370000e+02  VNZL            Venezuela   8.500000e+01  10.0  29.0
# 139   1.390000e+02  YMNR                Yemen   3.000000e+01  74.0   NaN
# 141   1.410000e+02  ZAIR                Zaire   4.000000e+01  39.0  42.0
# 143   1.430000e+02  ZIMB             Zimbabwe   2.800000e+01  40.0   NaN
# 145  1.571935e-317   FRG  Germany, West (FGR)   8.400000e+01   NaN   NaN
# 147  2.090000e-317  YMNA    Yemen ( Arab Rep)  1.831347e-317   NaN   NaN
#
#        V7             V8                                                 V9  \
# 131   NaN  4.770435e-312  1903598566251649928570260814834924381489212307...
# 133   NaN  1.431970e-314                                        4.66726e-62
# ...

# %%
## Selectin rows and columns at the same time.
WB_DF.iloc[[2,3], [1, 2]]
# Out:
#      V2       V3
# 3  ALGR  Algeria
# 4  ANGL   Angola

# %%
## Slice of rows and two columns
WB_DF.iloc[3:6, [1, 2]]
# Out:
#      V2         V3
# 4  ANGL     Angola
# 5  ARGN  Argentina
# 6  ARMN    Armenia

# %%
## Slice both rows and columns.
WB_DF.iloc[2:5, 2:5]
# Out:
#           V3    V4    V5
# 3    Algeria  53.0  55.0
# 4     Angola  28.0  72.0
# 5  Argentina  87.0   5.0

# %%
## Use .iloc to select one row and one column.
WB_DF.iloc[0, 2]
# Out:
# 'Afghanistan'

# %%
## All rows and one column.
WB_DF.iloc[:, 2]
# Out:
# 1               Afghanistan
# 2                   Albania
# 3                   Algeria
# 4                    Angola
# 5                 Argentina
# 6                   Armenia
# 7                 Australia
# 8                   Austria
# 9                Azerbaijan
# 10               Bangladesh
# 11                  Belarus
# 12                  Belgium
# 13                    Benin
# 14                   Bhutan
# 15                  Bolivia
# 16                 Botswana
# 17                   Brazil
# 18                 Bulgaria
# 19             Burkina Faso
# 20                  Burundi
# 21                 Cambodia
# 22                 Cameroon
# 23                   Canada
# 24     Central African Rep.
# 25                     Chad
# 26                    Chile
# 27                    China
# 28                 Colombia
# 29                    Congo
# 30               Costa Rica
#                ...
# 119                  Sweden
# 120             Switzerland
# ...

# %%
## Select one column as a series.
COUNTRY = WB_DF['V3']
COUNTRY
# Out:
# 1               Afghanistan
# 2                   Albania
# 3                   Algeria
# 4                    Angola
# 5                 Argentina
# 6                   Armenia
# 7                 Australia
# 8                   Austria
# 9                Azerbaijan
# 10               Bangladesh
# 11                  Belarus
# 12                  Belgium
# 13                    Benin
# 14                   Bhutan
# 15                  Bolivia
# 16                 Botswana
# 17                   Brazil
# 18                 Bulgaria
# 19             Burkina Faso
# 20                  Burundi
# 21                 Cambodia
# 22                 Cameroon
# 23                   Canada
# 24     Central African Rep.
# 25                     Chad
# 26                    Chile
# 27                    China
# 28                 Colombia
# 29                    Congo
# 30               Costa Rica
#                ...
# 119                  Sweden
# 120             Switzerland
# ...

# %%
## Now I take one value.
COUNTRY.loc[134]
# Out:
# 'United States'

# %%
## Now I return three values.
COUNTRY.loc[[133, 134, 1, 5]]
# Out:
# 133    United Kingdom
# 134     United States
# 1         Afghanistan
# 5           Argentina
# Name: V3, dtype: object

# %%
## Use a slice for indexing that includes the last one.
COUNTRY.loc[132:135]
# Out:
# 132    United Arab Emirates
# 133          United Kingdom
# 134           United States
# 135                 Uruguay
# Name: V3, dtype: object

# %%
## Slice until the end starting from 134.
COUNTRY.loc[134:]
# Out:
# 134          United States
# 135                Uruguay
# 136             Uzbekistan
# 137              Venezuela
# 138                Vietnam
# 139                  Yemen
# 140             Yugoslavia
# 141                  Zaire
# 142                 Zambia
# 143               Zimbabwe
# 144           Soviet Union
# 145    Germany, West (FGR)
# 146    Germany, East (GDR)
# 147      Yemen ( Arab Rep)
# 148            Yemen (PDR)
# Name: V3, dtype: object

# %%
## Single value that returns a Series.
COUNTRY.loc[[134]]
# Out:
# 134    United States
# Name: V3, dtype: object

# %%
## If I wanted to load the data with a column as the index for the rows, I use the code below.

WB_DF_idx = WB_DF.set_index('V3')
WB_DF_idx.head()
# Out:
#               V1    V2             V4    V5    V6    V7             V8  \
# V3
# Afghanistan  1.0  AFGN  1.831347e-317  86.0   NaN   NaN  4.770435e-312
# Albania      2.0  ALBN   3.500000e+01   NaN   NaN   NaN  4.770435e-312
# Algeria      3.0  ALGR   5.300000e+01  55.0  42.0  36.0  1.068570e-314
# Angola       4.0  ANGL   2.800000e+01  72.0  29.0   NaN  6.716447e-318
# Argentina    5.0  ARGN   8.700000e+01   5.0   NaN   NaN  1.068606e-314
#
#                                V9            V10            V11  \
# V3
# Afghanistan           4.66726e-62  1.992802e-314  1.992802e-314
# Albania               4.66726e-62  1.992802e-314  1.992802e-314
# Algeria      4.1517640553345e-317  1.992802e-314  2.820838e-318
# Angola                4.66726e-62  1.992802e-314  1.992802e-314
# Argentina           -1.54235e-180  2.279817e-319  6.757901e-317
#
#                                    ...                          V347  V348  \
# V3                                 ...
# ...

# %%
## Let's see if there are any missing values in V5.
FEM_LIT = WB_DF['V5']
FEM_LIT
# Out:
# 1      86.0
# 2       NaN
# 3      55.0
# 4      72.0
# 5       5.0
# 6       NaN
# 7       2.0
# 8       2.0
# 9       NaN
# 10     78.0
# 11      NaN
# 12      2.0
# 13     84.0
# 14     75.0
# 15     29.0
# 16     35.0
# 17     20.0
# 18      NaN
# 19     91.0
# 20     60.0
# 21     78.0
# 22     57.0
# 23      2.0
# 24     75.0
# 25     82.0
# 26      7.0
# 27     38.0
# 28     14.0
# 29     56.0
# 30      7.0
#        ...
# 119     2.0
# 120     2.0
# 121    49.0
# 122     NaN
# 123     NaN
# 124    10.0
# 125    69.0
# 126     NaN
# 127    44.0
# 128    29.0
# 129     NaN
# 130    65.0
# 131     NaN
# 132     NaN
# 133     2.0
# 134     2.0
# 135     4.0
# 136     NaN
# 137    10.0
# 138    16.0
# 139    74.0
# 140    12.0
# 141    39.0
# 142    35.0
# 143    40.0
# 144     NaN
# 145     NaN
# 146     NaN
# 147     NaN
# 148     NaN
# Name: V5, Length: 148, dtype: float64

# %%
## Let's check.
FEM_LIT.isnull()
# Out:
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9       True
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
#        ...
# 119    False
# 120    False
# 121    False
# 122     True
# 123     True
# 124    False
# 125    False
# 126     True
# 127    False
# 128    False
# 129     True
# 130    False
# 131     True
# 132     True
# 133    False
# 134    False
# 135    False
# 136     True
# 137    False
# 138    False
# 139    False
# 140    False
# 141    False
# 142    False
# 143    False
# 144     True
# 145     True
# 146     True
# 147     True
# 148     True
# Name: V5, Length: 148, dtype: bool

# %%
## Let me see only the non-missing values for female literacy.
FEM_LIT[FEM_LIT.notnull()]
# Out:
# 1      86.0
# 3      55.0
# 4      72.0
# 5       5.0
# 7       2.0
# 8       2.0
# 10     78.0
# 12      2.0
# 13     84.0
# 14     75.0
# 15     29.0
# 16     35.0
# 17     20.0
# 19     91.0
# 20     60.0
# 21     78.0
# 22     57.0
# 23      2.0
# 24     75.0
# 25     82.0
# 26      7.0
# 27     38.0
# 28     14.0
# 29     56.0
# 30      7.0
# 31     60.0
# 34      2.0
# 35     18.0
# 36     16.0
# 37     66.0
#        ...
# 101    12.0
# 102    21.0
# 103    11.0
# 105    19.0
# 109    63.0
# 110    52.0
# 111    75.0
# 112    89.0
# 114    86.0
# 116     7.0
# 117    17.0
# 118    88.0
# 119     2.0
# 120     2.0
# 121    49.0
# 124    10.0
# 125    69.0
# 127    44.0
# 128    29.0
# 130    65.0
# 133     2.0
# 134     2.0
# 135     4.0
# 137    10.0
# 138    16.0
# 139    74.0
# 140    12.0
# 141    39.0
# 142    35.0
# 143    40.0
# Name: V5, Length: 102, dtype: float64

# %%
## Now I drop all missing values
CLEAN_FEM_LIT = FEM_LIT.dropna()
CLEAN_FEM_LIT
# Out:
# 1      86.0
# 3      55.0
# 4      72.0
# 5       5.0
# 7       2.0
# 8       2.0
# 10     78.0
# 12      2.0
# 13     84.0
# 14     75.0
# 15     29.0
# 16     35.0
# 17     20.0
# 19     91.0
# 20     60.0
# 21     78.0
# 22     57.0
# 23      2.0
# 24     75.0
# 25     82.0
# 26      7.0
# 27     38.0
# 28     14.0
# 29     56.0
# 30      7.0
# 31     60.0
# 34      2.0
# 35     18.0
# 36     16.0
# 37     66.0
#        ...
# 101    12.0
# 102    21.0
# 103    11.0
# 105    19.0
# 109    63.0
# 110    52.0
# 111    75.0
# 112    89.0
# 114    86.0
# 116     7.0
# 117    17.0
# 118    88.0
# 119     2.0
# 120     2.0
# 121    49.0
# 124    10.0
# 125    69.0
# 127    44.0
# 128    29.0
# 130    65.0
# 133     2.0
# 134     2.0
# 135     4.0
# 137    10.0
# 138    16.0
# 139    74.0
# 140    12.0
# 141    39.0
# 142    35.0
# 143    40.0
# Name: V5, Length: 102, dtype: float64

# %%
## As we can see above, we only have 102 rows of non-missing values of FEM_LIT. Maybe I want to replace the missing values with a 0.
FILLED_FL = FEM_LIT.fillna(0)
FILLED_FL
# Out:
# 1      86.0
# 2       0.0
# 3      55.0
# 4      72.0
# 5       5.0
# 6       0.0
# 7       2.0
# 8       2.0
# 9       0.0
# 10     78.0
# 11      0.0
# 12      2.0
# 13     84.0
# 14     75.0
# 15     29.0
# 16     35.0
# 17     20.0
# 18      0.0
# 19     91.0
# 20     60.0
# 21     78.0
# 22     57.0
# 23      2.0
# 24     75.0
# 25     82.0
# 26      7.0
# 27     38.0
# 28     14.0
# 29     56.0
# 30      7.0
#        ...
# 119     2.0
# 120     2.0
# 121    49.0
# 122     0.0
# 123     0.0
# 124    10.0
# 125    69.0
# 126     0.0
# 127    44.0
# 128    29.0
# 129     0.0
# 130    65.0
# 131     0.0
# 132     0.0
# 133     2.0
# 134     2.0
# 135     4.0
# 136     0.0
# 137    10.0
# 138    16.0
# 139    74.0
# 140    12.0
# 141    39.0
# 142    35.0
# 143    40.0
# 144     0.0
# 145     0.0
# 146     0.0
# 147     0.0
# 148     0.0
# Name: V5, Length: 148, dtype: float64

# %%
## Now I'm going to get some descriptive statistics using grouped data. I'm using the variable V133 Civil Liberties
groups = WB_DF.groupby('V133')

groups

# %%
## Below is how we get the .sum() for the groups.
groups.sum()
# Out:
#           V1      V4      V5     V6     V7             V8            V10  \
# V133
# 1.0   1229.0  1333.0    42.0   90.0  403.0  1.447683e-313  8.429625e-314
# 2.0   1076.0   960.0   111.0  203.0  221.0  4.931644e-312  4.174024e-314
# 3.0   1102.0   763.0   354.0  405.0  428.0  6.720198e-314  6.024061e-314
# 4.0   1775.0  1198.0   913.0  702.0  478.0  9.667200e-312  1.998792e-313
# 5.0   1752.0   627.0  1101.0  734.0  213.0  4.862841e-312  2.394678e-313
# 6.0    991.0   429.0   678.0  390.0   85.0  4.770948e-312  1.795163e-313
# 7.0   1046.0   439.0   718.0  341.0   81.0  4.772148e-311  2.591283e-313
#
#                 V11            V12    V13   ...     V341    V342    V343  \
# V133                                        ...
# 1.0   1.161505e-313  6.768057e-316   76.0   ...    387.0    71.0   123.0
# 2.0   2.189271e-314  1.132738e-314  101.0   ...    379.0   265.0   278.0
# 3.0   2.060353e-314   1.050000e+02  250.0   ...    279.0   496.0   666.0
# ...

# %%
## Below we get all of the rows that are in the 7.0 group of Civil Liberties.
WB_DF.groupby('V133').get_group(7.0)
# Out:
#         V1    V2                 V3             V4    V5    V6    V7  \
# 1      1.0  AFGN        Afghanistan  1.831347e-317  86.0   NaN   NaN
# 4      4.0  ANGL             Angola   2.800000e+01  72.0  29.0   NaN
# 21    21.0  CMBA           Cambodia   1.200000e+01  78.0   NaN   NaN
# 27    27.0  CHNA              China   6.000000e+01  38.0  25.0  72.0
# 32    32.0  CUBA               Cuba  1.831347e-317   NaN   NaN   NaN
# 40    40.0  ETHP           Ethiopia   1.300000e+01   NaN   6.0   NaN
# 57    57.0  IRAQ               Iraq   7.100000e+01  51.0   NaN   NaN
# 66    66.0  NKOR  Korea North (PDR)  1.831347e-317   NaN   NaN   NaN
# 70    70.0  LAOP     Lao PDR (LAOS)   1.900000e+01   NaN  62.0   NaN
# 74    74.0  LBRA            Liberia   4.600000e+01  71.0   NaN   NaN
# 75    75.0  LBYA              Libya   7.000000e+01  55.0   NaN   NaN
# 88    88.0  MYNM    Myanmar (BURMA)   2.500000e+01  28.0  58.0   NaN
# 114  114.0  SMLA            Somalia  1.831347e-317  86.0  73.0   NaN
# ...

# %%
## Let's see how many countries are in each group.
groups.size()
# Out:
# V133
# 1.0    18
# 2.0    16
# 3.0    15
# 4.0    25
# 5.0    22
# 6.0    14
# 7.0    16
# dtype: int64

# %%
## Let's take a few statistics for % Female Illiteracy Rate
import numpy as np
groups['V5'].agg([np.sum, np.mean, np.std])
# Out:
#          sum       mean        std
# V133
# 1.0     42.0   2.625000   1.707825
# 2.0    111.0  10.090909  10.319443
# 3.0    354.0  27.230769  24.376060
# 4.0    913.0  45.650000  23.222664
# 5.0   1101.0  61.166667  23.843238
# 6.0    678.0  61.636364  14.562093
# 7.0    718.0  59.833333  24.112740

# %%
## We see above that illiteracy rate increases as civil liberties decrease (i.e., moves towards 7).
## Now I am going to add a variable with country code and name in the same variable.
WB_DF['Name_and_code'] = WB_DF.V2 + ', ' + WB_DF.V3
WB_DF.head()
# Out:
#     V1    V2           V3             V4    V5    V6    V7             V8  \
# 1  1.0  AFGN  Afghanistan  1.831347e-317  86.0   NaN   NaN  4.770435e-312
# 2  2.0  ALBN      Albania   3.500000e+01   NaN   NaN   NaN  4.770435e-312
# 3  3.0  ALGR      Algeria   5.300000e+01  55.0  42.0  36.0  1.068570e-314
# 4  4.0  ANGL       Angola   2.800000e+01  72.0  29.0   NaN  6.716447e-318
# 5  5.0  ARGN    Argentina   8.700000e+01   5.0   NaN   NaN  1.068606e-314
#
#                      V9            V10        ...          V348  \
# 1           4.66726e-62  1.992802e-314        ...           1.0
# 2           4.66726e-62  1.992802e-314        ...           0.0
# 3  4.1517640553345e-317  1.992802e-314        ...           0.0
# 4           4.66726e-62  1.992802e-314        ...           0.0
# 5         -1.54235e-180  2.279817e-319        ...           0.0
#
#             V349           V350  \
# 1  1.831347e-317  1.831347e-317
# 2   3.700000e+01   4.200000e+01
# ...

# %%
## Let's check how many countries are in each civil liberties group.
WB_DF.V133.value_counts()
# Out:
# 4.0    25
# 5.0    22
# 1.0    18
# 2.0    16
# 7.0    16
# 3.0    15
# 6.0    14
# Name: V133, dtype: int64

# %%
## Let's see how many unique values exist for POLITICAL RIGHTS 1991
WB_DF["V29"].unique()
# Out:
# array([ 7.,  4.,  1., nan,  5.,  6.,  2.,  3.])

# %%
## Let's see how many are in each group for the political rights variable.
WB_DF["V29"].value_counts()
# Out:
# 6.0    30
# 1.0    27
# 7.0    21
# 2.0    18
# 4.0    14
# 5.0     9
# 3.0     7
# Name: V29, dtype: int64

# %%
## Let's use Matplotlib to visualize our data.

import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('classic')

# %%
# %matplotlib inline

import numpy as np

# %%
## Let's look at the keys for our variables.
WB_DF.keys()
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        ...
#        'V348', 'V349', 'V350', 'V351', 'V352', 'V353', 'V354', 'V355', 'V356',
#        'Name_and_code'],
#       dtype='object', length=357)

# %%
## Let's look at the univariate distribution for Infant Mortality Rate.
plt.hist(WB_DF.V14)

# %%
## The same as above but with more detail.
plt.hist(WB_DF.V14, bins=30, normed=True, alpha=0.5,
         histtype='stepfilled', color='steelblue',
         edgecolor='none');
# Out:
# C:\Users\Juan Nunez\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
## Let's use seaborn now.
import seaborn as sns
sns.set()

# %%
## Let's take a subset of our data.
##V1 COUNTRY NUMBER ; 
##V2 ABBREVIATED COUNTRY NAME ; 
##V3 COUNTRY NAME ; 
##V5 % ADULT FEMALE ILLITERACY 1990 ; 
##V12 ENERGY CONSUMPTION/CAPITA 1991 ; 
##V14 INFANT MORTALITY RATE 1991 ; 
##V168 FEMALE SECODARY SCHOOL ENROLLMENT GROSS 1980 ; 
##V133 CIVIL LIBERTIES 1991 ; 
WB_DF6 = WB_DF.loc[:, ['V1', 'V2', 'V3','V5','V12','V14','V168','V133']]
WB_DF6.head()
# Out:
#     V1    V2           V3    V5            V12            V14  V168  V133
# 1  1.0  AFGN  Afghanistan  86.0   9.000000e+01  1.831347e-317   4.0   7.0
# 2  2.0  ALBN      Albania   NaN  1.849782e-319   2.800000e+01  63.0   6.0
# 3  3.0  ALGR      Algeria  55.0  4.682604e-317   6.400000e+01  26.0   4.0
# 4  4.0  ANGL       Angola  72.0  3.121704e-317   1.300000e+02   9.0   7.0
# 5  5.0  ARGN    Argentina   5.0  4.682225e-317   2.500000e+01  62.0   3.0

# %%
## Let's look at V5
WB_DF6['V5'].value_counts()
# Out:
# 2.0     17
# 7.0      4
# 30.0     3
# 75.0     3
# 29.0     3
# 79.0     3
# 12.0     3
# 86.0     2
# 52.0     2
# 11.0     2
# 53.0     2
# 87.0     2
# 66.0     2
# 16.0     2
# 27.0     2
# 62.0     2
# 57.0     2
# 60.0     2
# 35.0     2
# 10.0     2
# 78.0     2
# 55.0     2
# 49.0     2
# 82.0     1
# 91.0     1
# 20.0     1
# 38.0     1
# 14.0     1
# 56.0     1
# 18.0     1
# 84.0     1
# 5.0      1
# 72.0     1
# 40.0     1
# 39.0     1
# 19.0     1
# 74.0     1
# 4.0      1
# 65.0     1
# 44.0     1
# 69.0     1
# 88.0     1
# 17.0     1
# 89.0     1
# 63.0     1
# 21.0     1
# 51.0     1
# 61.0     1
# 83.0     1
# 28.0     1
# 15.0     1
# 76.0     1
# 71.0     1
# 33.0     1
# 42.0     1
# 1.0      1
# 32.0     1
# Name: V5, dtype: int64

# %%
import numpy as np
from pandas import DataFrame as df
from scipy.stats import trim_mean, kurtosis
from scipy.stats.mstats import mode, gmean, hmean
import pandas as pd

# %%
WB_DF6.describe()
# Out:
#                   V1          V5            V12            V14           V168  \
# count   1.480000e+02  102.000000   1.480000e+02   1.480000e+02   1.480000e+02
# mean    6.956757e+01   38.725490   1.375000e+01   4.897973e+01   3.329054e+01
# std     4.275514e+01   29.756822   2.986178e+01   4.293999e+01   3.349530e+01
# min    1.312902e-317    1.000000  1.849782e-319  1.048810e-317  1.831347e-317
# 25%     3.275000e+01   10.250000  3.121515e-317   1.400000e+01   2.750000e+00
# 50%     6.950000e+01   34.000000  6.751830e-317   3.550000e+01   2.050000e+01
# 75%     1.062500e+02   64.500000  1.065394e-314   8.300000e+01   6.350000e+01
# max     1.430000e+02   91.000000   1.470000e+02   1.490000e+02   1.050000e+02
#
#              V133
# count  126.000000
# mean     3.976190
# std      1.924429
# min      1.000000
# 25%      2.000000
# 50%      4.000000
# 75%      5.000000
# max      7.000000

# %%
WB_DF6.head()
# Out:
#     V1    V2           V3    V5            V12            V14  V168  V133
# 1  1.0  AFGN  Afghanistan  86.0   9.000000e+01  1.831347e-317   4.0   7.0
# 2  2.0  ALBN      Albania   NaN  1.849782e-319   2.800000e+01  63.0   6.0
# 3  3.0  ALGR      Algeria  55.0  4.682604e-317   6.400000e+01  26.0   4.0
# 4  4.0  ANGL       Angola  72.0  3.121704e-317   1.300000e+02   9.0   7.0
# 5  5.0  ARGN    Argentina   5.0  4.682225e-317   2.500000e+01  62.0   3.0

# %%
## Dropping all missing values
WB_DF6 = WB_DF6.dropna(how = 'any')
WB_DF6.head()
# Out:
#     V1    V2           V3    V5            V12            V14  V168  V133
# 1  1.0  AFGN  Afghanistan  86.0   9.000000e+01  1.831347e-317   4.0   7.0
# 3  3.0  ALGR      Algeria  55.0  4.682604e-317   6.400000e+01  26.0   4.0
# 4  4.0  ANGL       Angola  72.0  3.121704e-317   1.300000e+02   9.0   7.0
# 5  5.0  ARGN    Argentina   5.0  4.682225e-317   2.500000e+01  62.0   3.0
# 7  7.0  AUSL    Australia   2.0  2.969295e-317   8.000000e+00  72.0   1.0

# %%
## Below I create a dummy variable for V5
WB_DF6['LIT_DUM'] = WB_DF6.V5
mask = WB_DF6.LIT_DUM < 38
column_name = 'LIT_DUM'
WB_DF6.loc[mask, column_name] = 0
WB_DF6.head()
# Out:
#     V1    V2           V3    V5            V12            V14  V168  V133  \
# 1  1.0  AFGN  Afghanistan  86.0   9.000000e+01  1.831347e-317   4.0   7.0
# 3  3.0  ALGR      Algeria  55.0  4.682604e-317   6.400000e+01  26.0   4.0
# 4  4.0  ANGL       Angola  72.0  3.121704e-317   1.300000e+02   9.0   7.0
# 5  5.0  ARGN    Argentina   5.0  4.682225e-317   2.500000e+01  62.0   3.0
# 7  7.0  AUSL    Australia   2.0  2.969295e-317   8.000000e+00  72.0   1.0
#
#    LIT_DUM
# 1     86.0
# 3     55.0
# 4     72.0
# 5      0.0
# 7      0.0

# %%
mask2 = WB_DF6.LIT_DUM > 37
column_name1 = 'LIT_DUM'
WB_DF6.loc[mask2, column_name1] = 1
WB_DF6.head()
# Out:
#     V1    V2           V3    V5            V12            V14  V168  V133  \
# 1  1.0  AFGN  Afghanistan  86.0   9.000000e+01  1.831347e-317   4.0   7.0
# 3  3.0  ALGR      Algeria  55.0  4.682604e-317   6.400000e+01  26.0   4.0
# 4  4.0  ANGL       Angola  72.0  3.121704e-317   1.300000e+02   9.0   7.0
# 5  5.0  ARGN    Argentina   5.0  4.682225e-317   2.500000e+01  62.0   3.0
# 7  7.0  AUSL    Australia   2.0  2.969295e-317   8.000000e+00  72.0   1.0
#
#    LIT_DUM
# 1      1.0
# 3      1.0
# 4      1.0
# 5      0.0
# 7      0.0

# %%
## Let's look at LIT_DUM
WB_DF6['LIT_DUM'].value_counts()
# Out:
# 0.0    52
# 1.0    49
# Name: LIT_DUM, dtype: int64

# %%
## I could also recorde it like this.
WB_DF6.loc[(WB_DF6['V5'] > 0) & (WB_DF6['V5'] <= 38), 'LIT_DUM2'] = 'Hi_Lit'
WB_DF6.loc[(WB_DF6['V5'] > 38), 'LIT_DUM2'] = 'Lo_Lit'
WB_DF6.head()
# Out:
#     V1    V2           V3    V5            V12            V14  V168  V133  \
# 1  1.0  AFGN  Afghanistan  86.0   9.000000e+01  1.831347e-317   4.0   7.0
# 3  3.0  ALGR      Algeria  55.0  4.682604e-317   6.400000e+01  26.0   4.0
# 4  4.0  ANGL       Angola  72.0  3.121704e-317   1.300000e+02   9.0   7.0
# 5  5.0  ARGN    Argentina   5.0  4.682225e-317   2.500000e+01  62.0   3.0
# 7  7.0  AUSL    Australia   2.0  2.969295e-317   8.000000e+00  72.0   1.0
#
#    LIT_DUM LIT_DUM2 CIV_DUM
# 1      1.0   Lo_Lit  Lo_Civ
# 3      1.0   Lo_Lit  Lo_Civ
# 4      1.0   Lo_Lit  Lo_Civ
# 5      0.0   Hi_Lit  Hi_Civ
# 7      0.0   Hi_Lit  Hi_Civ

# %%
## I'll create a dummy for Civil Liberties.
WB_DF6.loc[(WB_DF6['V133'] > 0) & (WB_DF6['V133'] <= 3), 'CIV_DUM'] = 'Hi_Civ'
WB_DF6.loc[(WB_DF6['V133'] > 3), 'CIV_DUM'] = 'Lo_Civ'
WB_DF6.head()
# Out:
#     V1    V2           V3    V5            V12            V14  V168  V133  \
# 1  1.0  AFGN  Afghanistan  86.0   9.000000e+01  1.831347e-317   4.0   7.0
# 3  3.0  ALGR      Algeria  55.0  4.682604e-317   6.400000e+01  26.0   4.0
# 4  4.0  ANGL       Angola  72.0  3.121704e-317   1.300000e+02   9.0   7.0
# 5  5.0  ARGN    Argentina   5.0  4.682225e-317   2.500000e+01  62.0   3.0
# 7  7.0  AUSL    Australia   2.0  2.969295e-317   8.000000e+00  72.0   1.0
#
#    LIT_DUM LIT_DUM2 CIV_DUM
# 1      1.0   Lo_Lit  Lo_Civ
# 3      1.0   Lo_Lit  Lo_Civ
# 4      1.0   Lo_Lit  Lo_Civ
# 5      0.0   Hi_Lit  Hi_Civ
# 7      0.0   Hi_Lit  Hi_Civ

# %%
## Already we can see some association between LIT_DUM2 and CIV_DUM (i.e., those countries with low lit are also lo civ)
## Let's look at some distribution graphs.
grid = sns.FacetGrid(WB_DF6, row="LIT_DUM2", col="CIV_DUM", margin_titles=True)
grid.map(plt.hist, "V168", bins=np.linspace(0, 100, 20));

# %%
## We can see above that low civic liberties and low literacy rate are in the lower percentage of female school enrollment.
## Let's look at some factor plots.
with sns.axes_style(style='ticks'):
    g = sns.factorplot("LIT_DUM2", "V168", "CIV_DUM", data=WB_DF6, kind="box")
    g.set_axis_labels("Literacy", "Female School Enrollment");

# %%
## Let's see a bar chart of V168
with sns.axes_style('white'):
    g = sns.factorplot("V133", data=WB_DF6, aspect=2,
                       kind="count", color='steelblue')
    g.set_xticklabels(step=1)
